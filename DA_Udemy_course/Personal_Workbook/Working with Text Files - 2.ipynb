# %% [markdown]
# ## Importing .CSV file using pandas

# %%
filename = 'Lending-company.csv'

file = open(filename , mode = 'r')
text = file.read()
#print(text)
file.close()
file.closed
# Out:
# True

# %%
type(text)
# Out:
# str

# %%
import pandas as pd

# %%
pd.read_csv(filename)
# It create a DataFrame using the csv file
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
type(pd.read_csv(filename))
# Out:
# pandas.core.frame.DataFrame

# %%
filename = 'Lending-company.csv'
my_csv_data = pd.read_csv(filename)
my_csv_data

# Lending-company.csv --> file
# my_csv_data --> file object
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
type(my_csv_data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(my_csv_data)
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %% [markdown]
# ## Importing data with the "index_col" Parameter

# %%
filename = 'Lending-company.csv'
my_csv_data = pd.read_csv(filename, index_col='LoanID')
my_csv_data.head()
# Out:
#         StringID    Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       LoanID_1  Product B         Female   Location 3  Region 2     17600.0
# 2       LoanID_2  Product D         Female   Location 6  Region 6         NaN
# 3       LoanID_3  Product B           Male   Location 8  Region 3     16600.0
# 4       LoanID_4  Product A           Male  Location 26  Region 2     17600.0
# 5       LoanID_5  Product B         Female  Location 34  Region 3     21250.0
#
#          StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# LoanID
# 1       04/07/2018     2200         45          365       3221       4166
# 2       02/01/2019     2200         45          365       3161       4096
# 3       08/12/2016     1000         45          365       2260       3205
# 4              NaN     2200         45          365       3141       4166
# 5       28/10/2017     2200         55          365       3570       4745
#
#         AmtPaid360 LoanStatus
# ...

# %% [markdown]
# ## Importing Data with NumPy .loadtxt() vs .genfromtxt()

# %%
import numpy as np

# %%
# np.loadtxt() : "load" implies the data is ready to be used after imported directly
# np.genfromtxt() : "generate" indicates that the function cretes the dataset from the text file
# Generating requires constructing the array as we go through the text file.
# loadtext is more faster whereas genfromtxt() is more flexible

# %%
lending_co_data_numeric_1 = np.loadtxt("Lending-Company-Numeric-Data.csv", delimiter= ',')
lending_co_data_numeric_1
# Out:
# array([[ 2000.,    40.,   365.,  3121.,  4241., 13621.],
#        [ 2000.,    40.,   365.,  3061.,  4171., 15041.],
#        [ 1000.,    40.,   365.,  2160.,  3280., 15340.],
#        ...,
#        [ 2000.,    40.,   365.,  4201.,  5001., 16600.],
#        [ 1000.,    40.,   365.,  2080.,  3320., 15600.],
#        [ 2000.,    40.,   365.,  4601.,  4601., 16600.]])

# %%
lending_co_data_numeric_2 = np.genfromtxt("Lending-Company-Numeric-Data.csv", delimiter= ',')
lending_co_data_numeric_2
# Out:
# array([[ 2000.,    40.,   365.,  3121.,  4241., 13621.],
#        [ 2000.,    40.,   365.,  3061.,  4171., 15041.],
#        [ 1000.,    40.,   365.,  2160.,  3280., 15340.],
#        ...,
#        [ 2000.,    40.,   365.,  4201.,  5001., 16600.],
#        [ 1000.,    40.,   365.,  2080.,  3320., 15600.],
#        [ 2000.,    40.,   365.,  4601.,  4601., 16600.]])

# %%
np.array_equal(lending_co_data_numeric_1,lending_co_data_numeric_2)
# Out:
# True

# %%
lending_co_data_numeric_NaN = np.genfromtxt("Lending-Company-Numeric-Data-NAN.csv", delimiter= ';')
lending_co_data_numeric_NaN
# loadtxt is NOT working as NaN is not get handled from this function.
# Out:
# array([[ 2000.,    40.,   365.,  3121.,  4241., 13621.],
#        [ 2000.,    40.,   365.,  3061.,  4171., 15041.],
#        [ 1000.,    40.,   365.,  2160.,  3280., 15340.],
#        ...,
#        [   nan,    40.,   365.,  4201.,  5001., 16600.],
#        [ 1000.,    40.,   365.,  2080.,  3320., 15600.],
#        [ 2000.,    40.,   365.,  4601.,  4601., 16600.]])

# %%
#Hence we have converted all the values to string while using loadtxt function using dtype parameter
lending_co_data_numeric_NaN = np.loadtxt("Lending-Company-Numeric-Data-NAN.csv", delimiter= ';', dtype = np.str)
lending_co_data_numeric_NaN
# Out:
# C:\Users\Sourav Vishwakarma\AppData\Local\Temp\ipykernel_15956\3671737804.py:2: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   lending_co_data_numeric_NaN = np.loadtxt("Lending-Company-Numeric-Data-NAN.csv", delimiter= ';', dtype = np.str)
# array([['2000', '40', '365', '3121', '4241', '13621'],
#        ['2000', '40', '365', '3061', '4171', '15041'],
#        ['1000', '40', '365', '2160', '3280', '15340'],
#        ...,
#        ['', '40', '365', '4201', '5001', '16600'],
#        ['1000', '40', '365', '2080', '3320', '15600'],
#        ['2000', '40', '365', '4601', '4601', '16600']], dtype='<U5')

# %%
lending_co_data_numeric_NaN[0,0] + lending_co_data_numeric_NaN[0,1]
# Out:
# '200040'

# %% [markdown]
# ## Partially cleaning While importing - Numpy

# %%
lending_co_data_numeric_NaN = np.genfromtxt("Lending-Company-Numeric-Data-NAN.csv", delimiter= ';')
lending_co_data_numeric_NaN
# Out:
# array([[ 2000.,    40.,   365.,  3121.,  4241., 13621.],
#        [ 2000.,    40.,   365.,  3061.,  4171., 15041.],
#        [ 1000.,    40.,   365.,  2160.,  3280., 15340.],
#        ...,
#        [   nan,    40.,   365.,  4201.,  5001., 16600.],
#        [ 1000.,    40.,   365.,  2080.,  3320., 15600.],
#        [ 2000.,    40.,   365.,  4601.,  4601., 16600.]])

# %%
# SKIP HEADER and FOOTER
lending_co_data_numeric_NaN = np.genfromtxt("Lending-Company-Numeric-Data-NAN.csv",
                                            delimiter= ';',
                                           skip_header= 2,
                                           skip_footer = 2)
lending_co_data_numeric_NaN
# Out:
# array([[ 1000.,    40.,   365.,  2160.,  3280., 15340.],
#        [ 2000.,    40.,   365.,  3041.,  4241., 15321.],
#        [ 2000.,    50.,   365.,  3470.,  4820., 13720.],
#        ...,
#        [ 2000.,    40.,   365.,  3401.,    nan, 16600.],
#        [ 2000.,    40.,   365.,    nan,  5440., 16600.],
#        [   nan,    40.,   365.,  4201.,  5001., 16600.]])

# %%
# Fetch only columns
lending_co_data_numeric_NaN = np.genfromtxt("Lending-Company-Numeric-Data-NAN.csv", delimiter= ';',
                                           usecols= (0,1,5))
lending_co_data_numeric_NaN
# Out:
# array([[ 2000.,    40., 13621.],
#        [ 2000.,    40., 15041.],
#        [ 1000.,    40., 15340.],
#        ...,
#        [   nan,    40., 16600.],
#        [ 1000.,    40., 15600.],
#        [ 2000.,    40., 16600.]])

# %%
#Combine the clauses
lending_co_data_numeric_NaN = np.genfromtxt("Lending-Company-Numeric-Data-NAN.csv", delimiter= ';',
                                           usecols= (5,1,0),
                                           skip_header= 2,
                                           skip_footer = 2)
lending_co_data_numeric_NaN
# Out:
# array([[15340.,    40.,  1000.],
#        [15321.,    40.,  2000.],
#        [13720.,    50.,  2000.],
#        ...,
#        [16600.,    40.,  2000.],
#        [16600.,    40.,  2000.],
#        [16600.,    40.,    nan]])

# %%
# Split the data into multiple variables 
lending_co_data_numeric_5,lending_co_data_numeric_0,lending_co_data_numeric_1 = np.genfromtxt("Lending-Company-Numeric-Data-NAN.csv", delimiter= ';',
                                                                                       usecols= (5,0,1),
                                                                                       skip_header= 2,
                                                                                       skip_footer = 2, unpack= True)
print(lending_co_data_numeric_5)
print(lending_co_data_numeric_0)
print(lending_co_data_numeric_1)
# Out:
# [15340. 15321. 13720. ... 16600. 16600. 16600.]
# [1000. 2000. 2000. ... 2000. 2000.   nan]
# [40. 40. 50. ... 40. 40. 40.]

# %% [markdown]
# ## Importing JSON Files

# %%
# Concepts about JSON files :
# it is human readable
# it is an universal format
# it has been orgranised as plain text
# This file format is great for storing your info. in a structure that corresponds to a python directory.
# NO End of line present

# %%
prices_per_product = '{"Product A": 22250, "Product B" : 16600, "Product C": 15600}'
prices_per_product
# Out:
# '{"Product A": 22250, "Product B" : 16600, "Product C": 15600}'

# %%
type(prices_per_product)
# Out:
# str

# %%
import json

# %%
parsed_str = json.loads(prices_per_product)
parsed_str
# Out:
# {'Product A': 22250, 'Product B': 16600, 'Product C': 15600}

# %%
type(parsed_str)
# Out:
# dict

# %%
import pandas as pd

# %%
pd.read_json('Lending-company.json')
# Out:
#       Loan ID String_ID    Product CustomerGender      Location    Region  \
# 0           1      id_1  Product B           Male    Location 2  Region 2
# 1           2      id_2  Product B           Male    Location 3  Region 3
# 2           3      id_3  Product C         Female    Location 5  Region 5
# 3           4      id_4  Product B           Male    Location 6  Region 1
# 4           5      id_5  Product D         Female    Location 7  Region 2
# ...       ...       ...        ...            ...           ...       ...
# 1038     1039   id_1039  Product B         Female   Location 39  Region 6
# 1039     1040   id_1040  Product B           Male   Location 50  Region 1
# 1040     1041   id_1041  Product B           Male   Location 23  Region 4
# 1041     1042   id_1042  Product C   NotSpecified   Location 52  Region 6
# 1042     1043   id_1043  Product B         Female  Location 142  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDays  AmountPaid30  \
# ...

# %%
new_json_data = pd.read_json('Lending-company.json')
new_json_data
# Out:
#       Loan ID String_ID    Product CustomerGender      Location    Region  \
# 0           1      id_1  Product B           Male    Location 2  Region 2
# 1           2      id_2  Product B           Male    Location 3  Region 3
# 2           3      id_3  Product C         Female    Location 5  Region 5
# 3           4      id_4  Product B           Male    Location 6  Region 1
# 4           5      id_5  Product D         Female    Location 7  Region 2
# ...       ...       ...        ...            ...           ...       ...
# 1038     1039   id_1039  Product B         Female   Location 39  Region 6
# 1039     1040   id_1040  Product B           Male   Location 50  Region 1
# 1040     1041   id_1041  Product B           Male   Location 23  Region 4
# 1041     1042   id_1042  Product C   NotSpecified   Location 52  Region 6
# 1042     1043   id_1043  Product B         Female  Location 142  Region 6
#
#       TotalPrice   StartDate  Deposit  DailyRate  TotalDays  AmountPaid30  \
# ...

# %%
type(new_json_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Work with Excel data ( the *.xlsx format)

# %%
filename = 'Lending-company.xlsx'
#my_xlsx_data = pd.read_excel(filename)
my_xlsx_data = pd.read_excel(filename,index_col= 'LoanID')
my_xlsx_data
# Out:
#            StringID    Product CustomerGender     Location    Region  \
# LoanID
# 1          LoanID_1  Product B         Female   Location 3  Region 2
# 2          LoanID_2  Product D         Female   Location 6  Region 6
# 3          LoanID_3  Product B           Male   Location 8  Region 3
# 4          LoanID_4  Product A           Male  Location 26  Region 2
# 5          LoanID_5  Product B         Female  Location 34  Region 3
# ...             ...        ...            ...          ...       ...
# 1039    LoanID_1039  Product B           Male  Location 73  Region 6
# 1040    LoanID_1040  Product A           Male  Location 82  Region 1
# 1041    LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1042    LoanID_1042  Product B         Female  Location 26  Region 6
# 1043    LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
#         TotalPrice  StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# LoanID
# ...

# %%
type(my_xlsx_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## An important exercise on importing data in python

# %%
location_data = pd.read_csv('Lending-company.csv', usecols= ['StringID','Location','Region'], index_col= 'StringID')
location_data.head()
# Out:
#              Location    Region
# StringID
# LoanID_1   Location 3  Region 2
# LoanID_2   Location 6  Region 6
# LoanID_3   Location 8  Region 3
# LoanID_4  Location 26  Region 2
# LoanID_5  Location 34  Region 3

# %%
filename = 'Lending-company-single-column-data.csv'
my_csv_data = pd.read_csv(filename)
my_csv_data
# Out:
#      LoanID,StringID,Product,CustomerGender,Location,Region,TotalPrice,StartDate,Deposit,DailyRate,TotalDaysYr,AmtPaid36,AmtPaid60,AmtPaid360,LoanStatus
# 0     1,LoanID_1,Product B,Female,Location 3,Region ...
# 1     2,LoanID_2,Product D,Female,Location 6,Region ...
# 2     3,LoanID_3,Product B,Male,Location 8,Region 3,...
# 3     4,LoanID_4,Product A,Male,Location 26,Region 2...
# 4     5,LoanID_5,Product B,Female,Location 34,Region...
# ...                                                 ...
# 1038  1039,LoanID_1039,Product B,Male,Location 73,Re...
# 1039  1040,LoanID_1040,Product A,Male,Location 82,Re...
# 1040  1041,LoanID_1041,Product A,NotSpecified,Locati...
# 1041  1042,LoanID_1042,Product B,Female,Location 26,...
# 1042  1043,LoanID_1043,Product A,NotSpecified,Locati...
#
# [1043 rows x 1 columns]

# %%
filename = 'Lending-company-single-column-data.csv'
my_csv_data = pd.read_csv(filename, sep= '\,')
my_csv_data
# Out:
# C:\Users\Sourav Vishwakarma\AppData\Local\Temp\ipykernel_15956\206276817.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   my_csv_data = pd.read_csv(filename, sep= '\,')
#      "LoanID     StringID    Product CustomerGender     Location    Region  \
# 0         "1     LoanID_1  Product B         Female   Location 3  Region 2
# 1         "2     LoanID_2  Product D         Female   Location 6  Region 6
# 2         "3     LoanID_3  Product B           Male   Location 8  Region 3
# 3         "4     LoanID_4  Product A           Male  Location 26  Region 2
# 4         "5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038   "1039  LoanID_1039  Product B           Male  Location 73  Region 6
# ...

# %%
filename = 'Lending-company-single-column-data.csv'
my_csv_data = pd.read_csv(filename, sep= '\,', engine= 'python')
my_csv_data.head()
# Out:
#   "LoanID  StringID    Product CustomerGender     Location    Region  \
# 0      "1  LoanID_1  Product B         Female   Location 3  Region 2
# 1      "2  LoanID_2  Product D         Female   Location 6  Region 6
# 2      "3  LoanID_3  Product B           Male   Location 8  Region 3
# 3      "4  LoanID_4  Product A           Male  Location 26  Region 2
# 4      "5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus"
# 0       4166       14621     Active"
# 1       4096       16041     Active"
# ...

# %%
filename = 'Lending-company-single-column-data.csv'
my_csv_data = pd.read_csv(filename, delimiter= '\,', engine= 'python')
my_csv_data.head()
# Out:
#   "LoanID  StringID    Product CustomerGender     Location    Region  \
# 0      "1  LoanID_1  Product B         Female   Location 3  Region 2
# 1      "2  LoanID_2  Product D         Female   Location 6  Region 6
# 2      "3  LoanID_3  Product B           Male   Location 8  Region 3
# 3      "4  LoanID_4  Product A           Male  Location 26  Region 2
# 4      "5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus"
# 0       4166       14621     Active"
# 1       4096       16041     Active"
# ...

# %% [markdown]
# ## Importing Data with the pandas Squeeze Method

# %%
# Squeeze is a 1-D axis object into scalars.
# Series or Dataframes with a single element are squeezed to scalar.
#Dataframes with a single column or a single row are squeezed to a Series.

# %%
my_df = pd.read_csv('Lending-company.csv')
my_df.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# ...

# %%
df_single_col = pd.read_csv('Customer-Gender.csv')
df_single_col.head()
# Out:
#   CustomerGender
# 0         Female
# 1         Female
# 2           Male
# 3           Male
# 4         Female

# %%
type(df_single_col)
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.read_csv('Lending-company.csv')
df_squeeze = data.squeeze("columns")
df_squeeze.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# ...

# %%
type(df_squeeze)
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.read_csv('Lending-company.csv', usecols= ['Product'])
df_squeeze = data.squeeze("columns")
df_squeeze.head()
# Out:
# 0    Product B
# 1    Product D
# 2    Product B
# 3    Product A
# 4    Product B
# Name: Product, dtype: object

# %%
df_squeeze = data.squeeze(1)
df_squeeze
# Out:
# 0       Product B
# 1       Product D
# 2       Product B
# 3       Product A
# 4       Product B
#           ...
# 1038    Product B
# 1039    Product A
# 1040    Product A
# 1041    Product B
# 1042    Product A
# Name: Product, Length: 1043, dtype: object

# %%
type(df_squeeze)
# Out:
# pandas.core.series.Series

# %%
# .squeeze(0) = .squeeze("rows")
# .squeeze(1) = .squeeze("columns")

# %%
df_single_col = pd.read_csv('Customer-Gender.csv')
df_squeeze = df_single_col.squeeze(1)
df_squeeze.head()
# Out:
# 0    Female
# 1    Female
# 2      Male
# 3      Male
# 4    Female
# Name: CustomerGender, dtype: object

# %%
type(df_squeeze)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## A Note on importing Files in Jupyter

# %%
pd.read_csv('C:/Jupyter_Notebook/Personal_Workbook/Lending-company.csv')
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
import os, inspect

# %%
if '__file__' not in locals():
    fx = inspect.getframeinfo(inspect.currentframe())[0]
else:
    fx = __file__

# %%
os_dir = os.path.dirname(os.path.abspath(fx))
print(os_dir)
# This will show the current directory of working but for me it's showing wrong
# Out:
# C:\Users\Sourav Vishwakarma\AppData\Local\Temp\ipykernel_15956

# %%
#pd.read_csv(os.path.join(os_dir,"Lending-company.csv"))

# %% [markdown]
# ## Saving your Data from pandas

# %%
filename = 'Lending-company.csv'
my_data = pd.read_csv(filename)
my_data.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# ...

# %%
my_data.to_csv('my-csv-file.csv')

# %%
my_data.to_json('my-json-file.json')

# %%
my_data.to_excel('my-excel-file.xlsx')

# %%
my_data.to_excel('my-excel-file.xlsx', index= False)
# To remove the indexing from speadsheet

# %% [markdown]
# ## Saving Your Data with Numpy - np.save()

# %%
 import numpy as np

# %%
lending_co = np.genfromtxt('Lending-Company-Saving.csv',
                            delimiter= ',',
                            dtype = np.str)

print(lending_co)
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]
# C:\Users\Sourav Vishwakarma\AppData\Local\Temp\ipykernel_15956\3004535501.py:3: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.str)

# %%
np.save("Lending-Company-Saving", lending_co)
# It creates a .npy file in the same dir.
# NPY is a special type of text file native to Numpy
# NPY is much faster as compare to CSV
# It takes very less memory space.
# NPY is technically a text file

# %%
# Load a dataset =/= import a dataset
# importing doesn't keep a track of the datatype of the original array
# We need to specify the datatype of the values after having brought into Python
# When loading, We don't need to specify or change our data while working with our python object.

# %%
lending_data_save = np.load('Lending-Company-Saving.npy')

# %%
print(lending_data_save)
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
np.array_equal(lending_data_save,lending_co)
# Out:
# True

# %% [markdown]
# ## Saving Your Data with Numpy - np.savez()

# %%
import numpy as np

# %%
lending_co = np.genfromtxt('Lending-Company-Saving.csv',
                            delimiter= ',',
                            dtype = np.str)

lending_data_save = np.load('Lending-Company-Saving.npy')
# Out:
# C:\Users\Sourav Vishwakarma\AppData\Local\Temp\ipykernel_1996\2709638629.py:3: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.str)

# %%
np.savez('Lending-Company-Saving',lending_co)

# %%
# np.savez() doesn't create an .npy but an . npz
# the NPZ is like an archive of NPYs that can store multiple arrays
# Instead of storing different datasets in seperate NPY files, we can store all of them in single NPZ
# it is convinent in large amount of data

# %%
lending_data_savez = np.load('Lending-Company-Saving.npz')

# %%
print(lending_data_savez)

# %%
# This error come because NPZ contained collection of arrays
# It can't be properly displayed

# %%
#Rectification
print(lending_data_savez["arr_0"])
# ["arr_0"] = [0]
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
print(lending_data_savez["arr_1"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15956\1941012581.py in <module>
# ----> 1 print(lending_data_savez["arr_1"])
#
# C:\anaconda\lib\site-packages\numpy\lib\npyio.py in __getitem__(self, key)
#     258                 return self.zip.read(key)
#     259         else:
# --> 260             raise KeyError("%s is not a file in the archive" % key)
#     261
#     262
#
# KeyError: 'arr_1 is not a file in the archive'

# %%
np.savez('Lending-Company-Saving', company = lending_co, data_save = lending_data_save)

# %%
lending_data_savez = np.load("Lending-Company-Saving.npz")

# %%
lending_data_savez.files
# Out:
# ['company', 'data_save']

# %%
print(lending_data_savez["company"])
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
print(lending_data_savez["data_save"])
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
np.array_equal(lending_data_savez["company"],lending_data_savez["data_save"])
# Out:
# True

# %% [markdown]
# ## Saving Your Data with Numpy - np.savetxt()

# %%
lending_co = np.genfromtxt('Lending-Company-Saving.csv',
                            delimiter= ',',
                            dtype = np.str)
# Out:
# C:\Users\Sourav Vishwakarma\AppData\Local\Temp\ipykernel_15956\2540340210.py:3: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.str)

# %%
# np.savetxt() helps store numpy datasets in text files : .txt or .csv
# The syntax is once again very similar to np.save() and np.savez()

# %%
np.savetxt("Lending-Company-Saving.txt",lending_co,fmt= '%s', delimiter=',')

# %%
lending_data_savetxt = np.genfromtxt("Lending-Company-Saving.txt", delimiter= ',',dtype = np.str)
# Out:
# C:\Users\Sourav Vishwakarma\AppData\Local\Temp\ipykernel_15956\794720191.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   lending_data_savetxt = np.genfromtxt("Lending-Company-Saving.txt", delimiter= ',',dtype = np.str)

# %%
print(lending_data_savetxt)
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
lending_data_save = np.load("Lending-Company-Saving.npy")

# %%
np.array_equal(lending_data_savetxt,lending_data_save)
# Out:
# True
